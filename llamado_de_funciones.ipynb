# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import funciones as fun

# %%
df = fun.cargar_dataset('Mexico.csv')
df.head(5)
# Out:
#        id                                               name  host_id  \
# 0  499553      Deluxe 4-BR penthouse, views, historic center  1297488
# 1  501037                The best cheap flat in La Condesa!!  1364145
# 2  517503                         Nice big room near airport  2547499
# 3  527473  Nuestro bello departamento, un paraíso en la C...   158585
# 4  544105  Polanco great location! Priv Room in Shared Apart  2674950
#
#       host_name  neighbourhood_group        neighbourhood   latitude  \
# 0         Petra                  NaN           Cuauhtémoc  19.436210
# 1      Humberto                  NaN           Cuauhtémoc  19.415780
# 2  Irma Adriana                  NaN  Venustiano Carranza  19.437840
# 3      Fernando                  NaN           Cuauhtémoc  19.418870
# 4     Elizabeth                  NaN       Miguel Hidalgo  19.442892
#
#    longitude        room_type   price  minimum_nights  number_of_reviews  \
# ...

# %%
df1 = fun.reemplazar_nulos(df)
df1
# Out:
# /Users/carlosfonseca/Desktop/TEC UNI 6 SEMESTRE/Analisis de datos 1/UF1. Mtro Alfredo/Archivos de apoyo/Ejercicios/Examen_2/funciones.py:38: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(1000001, inplace=True)
# /Users/carlosfonseca/Desktop/TEC UNI 6 SEMESTRE/Analisis de datos 1/UF1. Mtro Alfredo/Archivos de apoyo/Ejercicios/Examen_2/funciones.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
cuenta_nulos = fun.cuenta_nulos(df1)
cuenta_nulos
# Out:
# ('Valores nulos por columna',
#  id                                0
#  name                              0
#  host_id                           0
#  host_name                         0
#  neighbourhood_group               0
#  neighbourhood                     0
#  latitude                          0
#  longitude                         0
#  room_type                         0
#  price                             0
#  minimum_nights                    0
#  number_of_reviews                 0
#  last_review                       0
#  reviews_per_month                 0
#  calculated_host_listings_count    0
#  availability_365                  0
#  number_of_reviews_ltm             0
#  license                           0
#  dtype: int64,
#  'Valores nulos por dataframe',
#  np.int64(0))

# %%
datos_limpios = fun.limpiar_atipicos(df1)
datos_limpios
# Out:
# /Users/carlosfonseca/Desktop/TEC UNI 6 SEMESTRE/Analisis de datos 1/UF1. Mtro Alfredo/Archivos de apoyo/Ejercicios/Examen_2/funciones.py:73: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Valor Atípico' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_nuevo.loc[i, col] = "Valor Atípico"
# /Users/carlosfonseca/Desktop/TEC UNI 6 SEMESTRE/Analisis de datos 1/UF1. Mtro Alfredo/Archivos de apoyo/Ejercicios/Examen_2/funciones.py:73: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Valor Atípico' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_nuevo.loc[i, col] = "Valor Atípico"
# ...

# %%
cuenta_nulos2 = fun.cuenta_nulos(datos_limpios)
cuenta_nulos2
# Out:
# ('Valores nulos por columna',
#  id                                0
#  name                              0
#  host_id                           0
#  host_name                         0
#  neighbourhood_group               0
#  neighbourhood                     0
#  latitude                          0
#  longitude                         0
#  room_type                         0
#  price                             0
#  minimum_nights                    0
#  number_of_reviews                 0
#  last_review                       0
#  reviews_per_month                 0
#  calculated_host_listings_count    0
#  availability_365                  0
#  number_of_reviews_ltm             0
#  license                           0
#  dtype: int64,
#  'Valores nulos por dataframe',
#  np.int64(0))

# %%
datos_limpios.to_csv("Datos_limpios_Examen.csv")
